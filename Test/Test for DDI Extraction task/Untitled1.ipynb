# %%
# %load extraction.py
import xml.etree.ElementTree

e = xml.etree.ElementTree.parse('DrugBank\Salsalate.xml').getroot()
# for atype in e.findall('sentence'):
#     print(atype.get('text'))

for atype in e.findall('sentence'):
    for entity in atype:
        print(entity.get('text'))
print(e)
# Out:
# Salicylates
# ASPIRIN
# SALICYLATE DRUGS
# DISALCID
# SALICYLIC ACID
# None
# None
# None
# None
# None
# None
# salicylic acid
# Salicylates
# anticoagulant drugs
# None
# Salicylates
# antidiabetic drugs
# None
# Salicylate
# penicillin
# thiopental
# thyroxine
# triiodothyronine
# phenytoin
# sulfinpyrazone
# naproxen
# warfarin
# methotrexate
# corticosteroids
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# Salicylate
# <Element 'document' at 0x000001A98FD76048>
